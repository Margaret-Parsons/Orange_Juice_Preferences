# %% [markdown]
# # **To Squeeze or Not to Squeeze🍊**
# **How do people prefer to drink their orange juice?**
#
# By: Maggie Parsons
#
# *View my GitHub:* https://github.com/Margaret-Parsons

# %% [markdown]
# #Introduction

# %% [markdown]
# When you picture a stereotypical American breakfast, many foods come to mind:
# sizzling bacon strips🥓, fried eggs🍳, fluffy pancakes🥞, mugs of steaming coffee☕, etc. However, one unsung breakfast beverage is oft left off the breakfast table- **orange juice**🍹. While too much sugar is never good for you, a tall glass of OJ provides many vitamins and-if you're a fan of pulp- fiber.
#
# **The goal of this study** is to determine which version of orange juice is better liked- and whether this preference changes across different communities (e.g., age groups, home states, etc.) The dataset will be continually updated as I continue to poll anyone I encounter who I am even vaguely acquainted with.

# %% [markdown]
# #Let's Get Juiced Up

# %% [markdown]
# To begin, let's load in the dataset. The CSV file we're storing the data in is stored in this project's GitHub repository, so let's clone it to gain access to the data. %ls will allow to confirm we can see the files in the repo (which we can!)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !git clone https://github.com/Margaret-Parsons/Orange_Juice_Preferences.git
# %cd Orange_Juice_Preferences
# %ls
# Out:
# Cloning into 'Orange_Juice_Preferences'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), 10.53 KiB | 10.53 MiB/s, done.
# /content/Orange_Juice_Preferences/Orange_Juice_Preferences
# Pulp_Preference_csv.csv  Pulp_Preference.xlsx  README.md

# %% [markdown]
# Now that we have access to the data we're looking at, let's load it in and take a look at the table.

# %%
oj_pref = pd.read_csv('Pulp_Preference_csv.csv', encoding = 'iso-8859-1')
oj_pref.head()
# Out:
#        Name   ID   Age Home_State Home_Country Affiliation_1 Afilliation_2  \
# 0    Maggie  M_1  21.0         NY           US            TU       NOLABJJ
# 1  Matthias  M_2  60.0        NaN           CH       NOLABJJ           NaN
# 2      Jeff  J_3   NaN        NaN           US       NOLABJJ           NaN
# 3    Thomas  T_4   NaN         TX           US       NOLABJJ           NaN
# 4     Keana  K_5  17.0         LA           US       NOLABJJ           NaN
#
#   Pulp_Preference
# 0             YES
# 1             YES
# 2             YES
# 3             YES
# 4             YES
